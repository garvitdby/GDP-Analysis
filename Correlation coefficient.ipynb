# %%
import pandas as pd

df = pd.read_excel('Final_dataset.xlsx')

column1 = df['Female Labor Force Participation Rate (%)']
column2 = df['GDP per capita (USD)']


correlation_coefficient = column1.corr(column2)

print(f"Correlation Coefficient between column1 and column2: {correlation_coefficient}")
# Out:
# Correlation Coefficient between column1 and column2: 0.5232919809732252

# %%
column3 = df['Female Labor Force Participation Rate (%)']
column4 = df['HDI Score']


correlation_coefficient = column3.corr(column4)

print(f"Correlation Coefficient between column3 and column4: {correlation_coefficient}")
# Out:
# Correlation Coefficient between column3 and column4: 0.5964369718855608

# %%
column5 = df['Debt to GDP ratio']
column6 = df['GDP Growth Rate (%)']


correlation_coefficient = column5.corr(column6)

print(f"Correlation Coefficient between column5 and column6: {correlation_coefficient}")
# Out:
# Correlation Coefficient between column5 and column6: -0.22311053417754118

# %%
column7 = df['GDP per capita (USD)']
column8 = df['Percentage of People with College Degree']


correlation_coefficient = column7.corr(column8)

print(f"Correlation Coefficient between column7 and column8: {correlation_coefficient}")
# Out:
# Correlation Coefficient between column7 and column8: 0.7541578491141172

# %%
column9 = df['GDP per capita (USD)']
column10 = df['R&D budget (% of GDP)']


correlation_coefficient = column9.corr(column10)

print(f"Correlation Coefficient between column9 and column10: {correlation_coefficient}")
# Out:
# Correlation Coefficient between column9 and column10: 0.5599818658216261

# %%
df.columns
# Out:
# Index(['Country', 'Size (sq km)', 'Population', 'Net Immigrant Population',
#        'Median age', 'HDI Score', 'GDP (USD Billion)', 'GNP (USD billions)',
#        'Agriculture (% in gdp)', 'Industry (% in gdp)', 'Services (% in gdp)',
#        'GDP Growth Rate (%)', 'GDP per capita (USD)', 'Debt to GDP ratio',
#        'Imports (billions)', 'Exports (billions)', 'FDI (USD Billion)',
#        'Percentage of People with College Degree',
#        'University graduates (% of adults)', 'Education Spending (% of GDP)',
#        'Defence spending(% of GDP)', 'Healthcare spending(% of GDP)',
#        'Infrastructure spending(% of GDP)',
#        'General public services spending (%of gdp)',
#        'Transportation and communication spending (%of gdp)',
#        'R&D budget (% of GDP)', 'Labor force participation rate (%)',
#        'Literacy rate (% of adults)', 'Access to internet (% of population)',
#        'Female Labor Force Participation Rate (%)', 'Inflation Rate (%)',
# ...
